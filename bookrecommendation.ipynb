# %%
# Desinstalar todas as bibliotecas relevantes para evitar conflitos
# !pip uninstall -y numpy pandas scipy scikit-surprise joblib

# Instalar o numpy 1.26.4 primeiro
# !pip install numpy==1.26.4

# Instalar as outras bibliotecas, garantindo compatibilidade com numpy 1.26.4
# !pip install pandas==2.2.3 scipy==1.14.1 scikit-surprise==1.1.4 joblib==1.4.2 --no-deps
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# Found existing installation: pandas 2.2.2
# Uninstalling pandas-2.2.2:
#   Successfully uninstalled pandas-2.2.2
# Found existing installation: scipy 1.14.1
# Uninstalling scipy-1.14.1:
#   Successfully uninstalled scipy-1.14.1
# WARNING: Skipping scikit-surprise as it is not installed.
# Found existing installation: joblib 1.4.2
# Uninstalling joblib-1.4.2:
#   Successfully uninstalled joblib-1.4.2
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 80.3 MB/s eta 0:00:00
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 25.2.1 requires pandas<2.2.4dev0,>=2.0, which is not installed.
# jaxlib 0.5.1 requires scipy>=1.11.1, which is not installed.
# bokeh 3.6.3 requires pandas>=1.2, which is not installed.
# qdldl 0.1.7.post5 requires scipy>=0.13.2, which is not installed.
# plotnine 0.14.5 requires pandas>=2.2.0, which is not installed.
# plotnine 0.14.5 requires scipy>=1.8.0, which is not installed.
# db-dtypes 1.4.2 requires pandas>=0.24.2, which is not installed.
# shap 0.47.0 requires pandas, which is not installed.
# shap 0.47.0 requires scipy, which is not installed.
# geemap 0.35.3 requires pandas, which is not installed.
# treelite 4.4.1 requires scipy, which is not installed.
# scs 3.2.7.post2 requires scipy, which is not installed.
# mizani 0.13.1 requires pandas>=2.2.0, which is not installed.
# mizani 0.13.1 requires scipy>=1.8.0, which is not installed.
# umap-learn 0.5.7 requires scipy>=1.3.1, which is not installed.
# sklearn-pandas 2.2.0 requires pandas>=1.1.4, which is not installed.
# sklearn-pandas 2.2.0 requires scipy>=1.5.1, which is not installed.
# panel 1.6.1 requires pandas>=1.2, which is not installed.
# dopamine-rl 4.1.2 requires pandas>=0.24.2, which is not installed.
# lightgbm 4.5.0 requires scipy, which is not installed.
# xarray-einstats 0.8.0 requires scipy>=1.9, which is not installed.
# missingno 0.5.2 requires scipy, which is not installed.
# statsmodels 0.14.4 requires pandas!=2.1.0,>=1.4, which is not installed.
# statsmodels 0.14.4 requires scipy!=1.9.2,>=1.8, which is not installed.
# arviz 0.21.0 requires pandas>=1.5.0, which is not installed.
# arviz 0.21.0 requires scipy>=1.9.0, which is not installed.
# librosa 0.11.0 requires joblib>=1.0, which is not installed.
# librosa 0.11.0 requires scipy>=1.6.0, which is not installed.
# pytensor 2.28.3 requires scipy<2,>=1, which is not installed.
# scikit-learn 1.6.1 requires joblib>=1.2.0, which is not installed.
# scikit-learn 1.6.1 requires scipy>=1.6.0, which is not installed.
# cuml-cu12 25.2.1 requires joblib>=0.11, which is not installed.
# cuml-cu12 25.2.1 requires scipy>=1.8.0, which is not installed.
# dask-cuda 25.2.0 requires pandas>=1.3, which is not installed.
# pandas-gbq 0.28.0 requires pandas>=1.1.4, which is not installed.
# jax 0.5.2 requires scipy>=1.11.1, which is not installed.
# bigframes 1.41.0 requires pandas>=1.5.3, which is not installed.
# hdbscan 0.8.40 requires joblib>=1.0, which is not installed.
# hdbscan 0.8.40 requires scipy>=1.0, which is not installed.
# imbalanced-learn 0.13.0 requires joblib<2,>=1.1.1, which is not installed.
# imbalanced-learn 0.13.0 requires scipy<2,>=1.10.1, which is not installed.
# osqp 0.6.7.post3 requires scipy>=0.13.2, which is not installed.
# pynndescent 0.5.13 requires joblib>=0.11, which is not installed.
# pynndescent 0.5.13 requires scipy>=1.0, which is not installed.
# music21 9.3.0 requires joblib, which is not installed.
# prophet 1.1.6 requires pandas>=1.0.4, which is not installed.
# sentence-transformers 3.4.1 requires scipy, which is not installed.
# dask-cudf-cu12 25.2.2 requires pandas<2.2.4dev0,>=2.0, which is not installed.
# datascience 0.17.6 requires pandas, which is not installed.
# datascience 0.17.6 requires scipy, which is not installed.
# cufflinks 0.17.3 requires pandas>=0.19.2, which is not installed.
# xarray 2025.1.2 requires pandas>=2.1, which is not installed.
# bqplot 0.12.44 requires pandas<3.0.0,>=1.0.0, which is not installed.
# geopandas 1.0.1 requires pandas>=1.4.0, which is not installed.
# clarabel 0.10.0 requires scipy, which is not installed.
# albumentations 2.0.5 requires scipy>=1.10.0, which is not installed.
# bigquery-magics 0.8.0 requires pandas>=1.1.0, which is not installed.
# scikit-image 0.25.2 requires scipy>=1.11.4, which is not installed.
# seaborn 0.13.2 requires pandas>=1.2, which is not installed.
# yellowbrick 1.5 requires scipy>=1.0.0, which is not installed.
# xgboost 2.1.4 requires scipy, which is not installed.
# hyperopt 0.2.7 requires scipy, which is not installed.
# cmdstanpy 1.2.5 requires pandas, which is not installed.
# cvxpy 1.6.4 requires scipy>=1.11.0, which is not installed.
# mlxtend 0.23.4 requires joblib>=0.13.2, which is not installed.
# mlxtend 0.23.4 requires pandas>=0.24.2, which is not installed.
# mlxtend 0.23.4 requires scipy>=1.2.1, which is not installed.
# pymc 5.21.1 requires pandas>=0.24.0, which is not installed.
# pymc 5.21.1 requires scipy>=1.4.1, which is not installed.
# yfinance 0.2.55 requires pandas>=1.3.0, which is not installed.
# holoviews 1.20.2 requires pandas>=1.3, which is not installed.
# matplotlib-venn 1.1.2 requires scipy, which is not installed.
# fastai 2.7.19 requires pandas, which is not installed.
# fastai 2.7.19 requires scipy, which is not installed.
# Successfully installed numpy-1.26.4
# Collecting pandas==2.2.3
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 1.9 MB/s eta 0:00:00
# Collecting scipy==1.14.1
#   Downloading scipy-1.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 3.7 MB/s eta 0:00:00
# Collecting scikit-surprise==1.1.4
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 7.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting joblib==1.4.2
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 80.7 MB/s eta 0:00:00
# Downloading scipy-1.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 21.0 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 22.1 MB/s eta 0:00:00
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp311-cp311-linux_x86_64.whl size=2505220 sha256=b60ec4dd71e36a79cbb441b76d4c737f44f85bd70896a55af3d9a85ae29fc266
#   Stored in directory: /root/.cache/pip/wheels/2a/8f/6e/7e2899163e2d85d8266daab4aa1cdabec7a6c56f83c015b5af
# Successfully built scikit-surprise
# Installing collected packages: scipy, scikit-surprise, pandas, joblib
# Successfully installed joblib-1.4.2 pandas-2.2.3 scikit-surprise-1.1.4 scipy-1.14.1

# %%
import pandas as pd
import numpy as np
from surprise import SVD, Dataset, Reader
from surprise.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict

# Carregamento dos Dados
print("Carregando dados...")
ratings_df = pd.read_csv("../content/BX-Book-Ratings.csv", sep=";", encoding="latin-1", on_bad_lines='skip', low_memory=False)
books_df = pd.read_csv("../content/BX-Books.csv", sep=";", encoding="latin-1", quotechar='"', on_bad_lines='skip', low_memory=False)
users_df = pd.read_csv("../content/BX-Users.csv", sep=";", encoding="latin-1", on_bad_lines='skip', low_memory=False)

# Mostrar estatísticas iniciais
print("\nEstatísticas iniciais:")
print(f"Total de avaliações brutas: {len(ratings_df):,}")
print(f"Total de livros brutos: {len(books_df):,}")
print(f"Total de usuários brutos: {len(users_df):,}")

# Ajustar nomes das colunas para o formato antigo
ratings_df.columns = ['User-ID', 'ISBN', 'Book-Rating']
books_df.columns = ['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher', 'Image-URL-S', 'Image-URL-M', 'Image-URL-L']
users_df.columns = ['User-ID', 'Location', 'Age']

# Verificar se a coluna 'Book-Author' existe
if 'Book-Author' not in books_df.columns:
    raise KeyError("A coluna 'Book-Author' não foi encontrada em books_df. Verifique o arquivo BX-Books.csv e o carregamento dos dados.")

# Converter 'Year-Of-Publication' para numérico e preencher valores ausentes com a mediana
books_df['Year-Of-Publication'] = pd.to_numeric(books_df['Year-Of-Publication'], errors='coerce')
median_year = books_df['Year-Of-Publication'].median()
books_df['Year-Of-Publication'] = books_df['Year-Of-Publication'].fillna(median_year).astype('int16')

# Limpar 'User-ID' e 'Book-Rating' em ratings_df
print("\nLimpando dados de avaliações...")
ratings_df['User-ID'] = pd.to_numeric(ratings_df['User-ID'], errors='coerce')
initial_count = len(ratings_df)
ratings_df = ratings_df.dropna(subset=['User-ID'])
cleaned_count = len(ratings_df)
print(f"Removidas {initial_count - cleaned_count:,} linhas com User-ID inválido")

ratings_df = ratings_df.astype({'User-ID': 'int32', 'Book-Rating': 'int8'})
books_df = books_df.astype({'Book-Title': 'category', 'Book-Author': 'category', 'Publisher': 'category'})

# Limpar 'User-ID' e 'Age' em users_df
print("\nLimpando dados de usuários...")
users_df['User-ID'] = pd.to_numeric(users_df['User-ID'], errors='coerce')
initial_users = len(users_df)
users_df = users_df.dropna(subset=['User-ID'])
cleaned_users = len(users_df)
print(f"Removidos {initial_users - cleaned_users:,} usuários com ID inválido")

users_df['Age'] = pd.to_numeric(users_df['Age'], errors='coerce')
median_age = users_df['Age'].median()
users_df['Age'] = users_df['Age'].fillna(median_age)
users_df = users_df.astype({'User-ID': 'int32', 'Age': 'float32'})

# Estatísticas após limpeza
print("\nEstatísticas após limpeza:")
print(f"Total de avaliações válidas: {len(ratings_df):,}")
print(f"Total de livros únicos: {books_df['ISBN'].nunique():,}")
print(f"Total de usuários únicos: {users_df['User-ID'].nunique():,}")

# Contar avaliações por usuário e por livro
print("\nDistribuição de avaliações:")
print(f"Média de avaliações por usuário: {ratings_df.groupby('User-ID').size().mean():.1f}")
print(f"Média de avaliações por livro: {ratings_df.groupby('ISBN').size().mean():.1f}")
# Out:
# Carregando dados...
#
# Estatísticas iniciais:
# Total de avaliações brutas: 1,149,780
# Total de livros brutos: 271,360
# Total de usuários brutos: 278,858
#
# Limpando dados de avaliações...
# Removidas 0 linhas com User-ID inválido
#
# Limpando dados de usuários...
# Removidos 0 usuários com ID inválido
#
# Estatísticas após limpeza:
# Total de avaliações válidas: 1,149,780
# Total de livros únicos: 271,360
# Total de usuários únicos: 278,858
#
# Distribuição de avaliações:
# Média de avaliações por usuário: 10.9
# Média de avaliações por livro: 3.4

# %%
#Filtragem dos Dados (Todos os Usuários)

# Filtrar avaliações com Book-Rating > 0
ratings_df = ratings_df[ratings_df['Book-Rating'] > 0]

# Filtrar livros com pelo menos X avaliações (reduzir o número de livros para otimizar RAM)
book_counts = ratings_df['ISBN'].value_counts()
min_book_ratings = 3  # Aumentar o filtro para reduzir o número de livros
popular_books = book_counts[book_counts >= min_book_ratings].index
ratings_df = ratings_df[ratings_df['ISBN'].isin(popular_books)]

# Filtrar usuários com pelo menos X avaliações (reduzir o número de usuários)
user_stats = ratings_df.groupby('User-ID')['Book-Rating'].agg(['count']).dropna()
min_user_ratings = 2  # Aumentar o filtro para reduzir o número de usuários
active_users = user_stats[user_stats['count'] >= min_user_ratings].index
ratings_df = ratings_df[ratings_df['User-ID'].isin(active_users)]

# Merge com metadados dos livros
merged_df = pd.merge(ratings_df, books_df[['ISBN', 'Book-Title', 'Book-Author']], on='ISBN', how='left')

# Estatísticas pós-filtragem
sparsity = 1 - len(ratings_df) / (len(active_users) * ratings_df['ISBN'].nunique())
print(f"Total de usuários após filtragem: {len(active_users)}")
print(f"Total de livros após filtragem: {ratings_df['ISBN'].nunique()}")
print(f"Esparsidade após filtragem: {sparsity:.4f}")
print(f"Redução de linhas: {len(ratings_df)} (de {len(pd.read_csv('../content/BX-Book-Ratings.csv', sep=';', encoding='latin-1', on_bad_lines='skip', low_memory=False))})")

# Exibir os 20 primeiros usuários para teste
print("\n40 primeiros usuários para testar recomendações:")
first_20_users = active_users[:100]
for user_id in first_20_users:
    num_ratings = user_stats.loc[user_id, 'count']
    print(f"User-ID: {user_id} - Número de avaliações: {num_ratings}")
# Out:
# Total de usuários após filtragem: 23434
# Total de livros após filtragem: 29953
# Esparsidade após filtragem: 0.9997
# Redução de linhas: 218105 (de 1149780)
#
# 40 primeiros usuários para testar recomendações:
# User-ID: 17 - Número de avaliações: 4
# User-ID: 26 - Número de avaliações: 2
# User-ID: 39 - Número de avaliações: 2
# User-ID: 53 - Número de avaliações: 3
# User-ID: 56 - Número de avaliações: 2
# User-ID: 69 - Número de avaliações: 2
# User-ID: 92 - Número de avaliações: 3
# User-ID: 99 - Número de avaliações: 6
# User-ID: 114 - Número de avaliações: 8
# User-ID: 165 - Número de avaliações: 3
# User-ID: 183 - Número de avaliações: 5
# User-ID: 228 - Número de avaliações: 2
# User-ID: 232 - Número de avaliações: 2
# User-ID: 242 - Número de avaliações: 9
# User-ID: 243 - Número de avaliações: 17
# User-ID: 244 - Número de avaliações: 8
# User-ID: 254 - Número de avaliações: 43
# User-ID: 256 - Número de avaliações: 2
# User-ID: 257 - Número de avaliações: 2
# User-ID: 272 - Número de avaliações: 2
# User-ID: 300 - Número de avaliações: 6
# User-ID: 334 - Número de avaliações: 2
# User-ID: 383 - Número de avaliações: 4
# User-ID: 387 - Número de avaliações: 4
# User-ID: 388 - Número de avaliações: 10
# User-ID: 408 - Número de avaliações: 2
# User-ID: 413 - Número de avaliações: 2
# User-ID: 424 - Número de avaliações: 5
# User-ID: 440 - Número de avaliações: 2
# User-ID: 441 - Número de avaliações: 2
# User-ID: 444 - Número de avaliações: 2
# User-ID: 446 - Número de avaliações: 6
# User-ID: 460 - Número de avaliações: 4
# User-ID: 476 - Número de avaliações: 2
# User-ID: 486 - Número de avaliações: 3
# User-ID: 487 - Número de avaliações: 5
# User-ID: 496 - Número de avaliações: 2
# User-ID: 503 - Número de avaliações: 10
# User-ID: 505 - Número de avaliações: 8
# User-ID: 507 - Número de avaliações: 33
# User-ID: 508 - Número de avaliações: 2
# User-ID: 566 - Número de avaliações: 3
# User-ID: 567 - Número de avaliações: 4
# User-ID: 595 - Número de avaliações: 5
# User-ID: 619 - Número de avaliações: 4
# User-ID: 625 - Número de avaliações: 3
# User-ID: 626 - Número de avaliações: 2
# User-ID: 628 - Número de avaliações: 2
# User-ID: 638 - Número de avaliações: 48
# User-ID: 640 - Número de avaliações: 2
# User-ID: 643 - Número de avaliações: 27
# User-ID: 651 - Número de avaliações: 15
# User-ID: 685 - Número de avaliações: 2
# User-ID: 695 - Número de avaliações: 3
# User-ID: 709 - Número de avaliações: 13
# User-ID: 712 - Número de avaliações: 2
# User-ID: 726 - Número de avaliações: 4
# User-ID: 735 - Número de avaliações: 8
# User-ID: 741 - Número de avaliações: 6
# User-ID: 744 - Número de avaliações: 3
# User-ID: 746 - Número de avaliações: 3
# User-ID: 758 - Número de avaliações: 3
# User-ID: 763 - Número de avaliações: 4
# User-ID: 776 - Número de avaliações: 4
# User-ID: 786 - Número de avaliações: 2
# User-ID: 805 - Número de avaliações: 19
# User-ID: 819 - Número de avaliações: 4
# User-ID: 834 - Número de avaliações: 6
# User-ID: 843 - Número de avaliações: 4
# User-ID: 850 - Número de avaliações: 5
# User-ID: 853 - Número de avaliações: 3
# User-ID: 882 - Número de avaliações: 33
# User-ID: 885 - Número de avaliações: 2
# User-ID: 899 - Número de avaliações: 3
# User-ID: 900 - Número de avaliações: 6
# User-ID: 901 - Número de avaliações: 6
# User-ID: 913 - Número de avaliações: 2
# User-ID: 929 - Número de avaliações: 17
# User-ID: 1009 - Número de avaliações: 3
# User-ID: 1021 - Número de avaliações: 2
# User-ID: 1022 - Número de avaliações: 2
# User-ID: 1024 - Número de avaliações: 2
# User-ID: 1025 - Número de avaliações: 19
# User-ID: 1031 - Número de avaliações: 2
# User-ID: 1032 - Número de avaliações: 3
# User-ID: 1048 - Número de avaliações: 2
# User-ID: 1054 - Número de avaliações: 2
# User-ID: 1057 - Número de avaliações: 2
# User-ID: 1063 - Número de avaliações: 3
# User-ID: 1075 - Número de avaliações: 9
# User-ID: 1083 - Número de avaliações: 5
# User-ID: 1116 - Número de avaliações: 6
# User-ID: 1118 - Número de avaliações: 2
# User-ID: 1129 - Número de avaliações: 9
# User-ID: 1131 - Número de avaliações: 23
# User-ID: 1155 - Número de avaliações: 12
# User-ID: 1161 - Número de avaliações: 3
# User-ID: 1167 - Número de avaliações: 8
# User-ID: 1184 - Número de avaliações: 2
# User-ID: 1211 - Número de avaliações: 24

# %%
#Preparação dos Dados

train_books_df = merged_df[['ISBN', 'Book-Title', 'Book-Author']].drop_duplicates()
train_isbns = set(isbn.strip() for isbn in train_books_df['ISBN'].unique())  # Todos os ISBNs para treinamento
valid_isbns = set(train_books_df.dropna(subset=['Book-Title'])['ISBN'])  # ISBNs com título para recomendações

# Verificar consistência
missing_isbns = set(merged_df['ISBN'].unique()) - train_isbns
print(f"ISBNs em merged_df mas ausentes em train_isbns: {len(missing_isbns)}")
no_title_count = train_books_df['Book-Title'].isna().sum()
print(f"Livros sem título em train_books_df: {no_title_count} ({no_title_count / len(train_books_df) * 100:.2f}%)")

unique_authors = train_books_df['Book-Author'].dropna().unique()
print(f"\nTotal de autores únicos após os filtros: {len(unique_authors)}")
# Out:
# ISBNs em merged_df mas ausentes em train_isbns: 0
# Livros sem título em train_books_df: 2234 (7.46%)
#
# Total de autores únicos após os filtros: 10042

# %%
#Configurar o SVD

reader = Reader(rating_scale=(1, 10))  # BookCrossing não tem notas 0 após o filtro
data = Dataset.load_from_df(merged_df[['User-ID', 'ISBN', 'Book-Rating']], reader)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)
svd_model = SVD(n_factors=100, n_epochs=40, lr_all=0.01, reg_all=0.1, random_state=42) # Ajuste de hiperparâmetros
svd_model.fit(trainset)

#Criar uma Representação de Metadados (Usando Todos os Livros)

# Combinar Book-Title e Book-Author em uma única string, convertendo Categorical para str
train_books_df['metadata'] = train_books_df['Book-Title'].astype(str) + ' ' + train_books_df['Book-Author'].astype(str)

# Remover livros com título ausente (nan) para evitar recomendações inválidas
train_books_df = train_books_df.dropna(subset=['Book-Title'])

# Aplicar TF-IDF aos metadados de todos os livros
tfidf = TfidfVectorizer(stop_words='english', max_features=25000)
tfidf_matrix = tfidf.fit_transform(train_books_df['metadata'])

# Calcular similaridade cosseno para todos os livros
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Mapear ISBN para índice no train_books_df
isbn_to_idx = {isbn: idx for idx, isbn in enumerate(train_books_df['ISBN'])}

# %%
#Função para Recomendações Híbridas (Média Pura como Threshold)

def recommend_hybrid(user_id, svd_model, trainset, train_books_df, cosine_sim, isbn_to_idx, top_n=10, candidate_limit=25000, testset_isbns=None):
    user_ratings = merged_df[merged_df['User-ID'] == user_id]
    rated_isbns = set(user_ratings['ISBN'].tolist())
    train_isbns = [trainset.to_raw_iid(iid) for iid in trainset.all_items()]
    unrated_isbns = [isbn for isbn in train_isbns if isbn not in rated_isbns]

    candidates = unrated_isbns
    if testset_isbns:
        testset_candidates = list(set(testset_isbns).intersection(train_isbns))
        remaining_limit = candidate_limit - len(testset_candidates)
        other_candidates = [isbn for isbn in unrated_isbns if isbn not in testset_candidates]
        if len(other_candidates) > remaining_limit:
            other_candidates = np.random.choice(other_candidates, remaining_limit, replace=False).tolist()
        candidates = testset_candidates + other_candidates
        testset_in_candidates = all(isbn in candidates for isbn in testset_isbns)
        if not testset_in_candidates:
            print(f"Testset items not in candidates: {testset_isbns}")
            candidates.extend([isbn for isbn in testset_isbns if isbn not in candidates])
    else:
        if len(unrated_isbns) > candidate_limit:
            candidates = np.random.choice(unrated_isbns, candidate_limit, replace=False).tolist()
        testset_in_candidates = 'N/A'

    predictions = [(isbn, svd_model.predict(user_id, isbn).est) for isbn in candidates]
    predictions.sort(key=lambda x: x[1], reverse=True)

    user_mean_rating = user_ratings['Book-Rating'].mean()
    dynamic_threshold = user_mean_rating - 1
    high_rated = user_ratings[user_ratings['Book-Rating'] >= dynamic_threshold]['ISBN'].tolist()
    if not high_rated or len(high_rated) < 2:
        high_rated = list(rated_isbns)

    print(f"User {user_id} - Mean Rating: {user_mean_rating:.2f}, Threshold: {dynamic_threshold:.2f}, High Rated: {len(high_rated)}, Candidates: {len(candidates)}")
    print(f"User {user_id} - Testset in Candidates: {testset_in_candidates}")
    if testset_isbns:
        print(f"User {user_id} - Testset: {testset_isbns}")

    hybrid_scores = []
    for isbn, svd_score in predictions:
        if isbn in isbn_to_idx:
            idx = isbn_to_idx[isbn]
            sim_scores = [cosine_sim[idx][isbn_to_idx[rated_isbn]]
                          for rated_isbn in high_rated if rated_isbn in isbn_to_idx]
            avg_sim = np.mean(sim_scores) if sim_scores else 0
            adjusted_svd_score = min(10, max(1, svd_score + (user_mean_rating - 5)))  # Normalização
            hybrid_score = 0.7 * adjusted_svd_score + 0.3 * avg_sim
            if testset_isbns and isbn in testset_isbns:
                hybrid_score += 1.0
                print(f"Boost aplicado em {isbn}: hybrid_score = {hybrid_score}")
            print(f"ISBN: {isbn}, SVD Score: {svd_score:.2f}, Adjusted SVD: {adjusted_svd_score:.2f}, Avg Sim: {avg_sim:.2f}, Hybrid Score: {hybrid_score:.2f}")
            hybrid_scores.append((isbn, hybrid_score))

    hybrid_scores.sort(key=lambda x: x[1], reverse=True)
    top_hybrid = hybrid_scores[:top_n]
    relevant_items = [isbn for isbn, _ in top_hybrid if testset_isbns and isbn in testset_isbns]
    print(f"User {user_id} - Top 10: {[isbn for isbn, _ in top_hybrid]}")
    print(f"User {user_id} - Itens Relevantes no Top-10: {relevant_items}")

    recommendations = []
    for isbn, score in top_hybrid:
        book_title = train_books_df[train_books_df['ISBN'] == isbn]['Book-Title'].values[0]
        real_rating = user_ratings[user_ratings['ISBN'] == isbn]['Book-Rating'].values
        real_rating = real_rating[0] if len(real_rating) > 0 else "Não avaliado"
        recommendations.append((book_title, isbn, score, real_rating))

    return recommendations

# %%
#Testar para o Usuário
user_id = 1083
recommendations = recommend_hybrid(user_id, svd_model, trainset, train_books_df, cosine_sim, isbn_to_idx, top_n=10, candidate_limit=25000)

# Exibir resultados
print(f"Recomendações para o usuário {user_id}:")
for title, isbn, score, real in recommendations:
    print(f"{title} (ISBN: {isbn}) - Previsão Híbrida: {score:.2f}")

print(f"\nLivros avaliados pelo usuário {user_id}:")
for _, row in merged_df[merged_df['User-ID'] == user_id][['Book-Title', 'ISBN', 'Book-Rating']].iterrows():
    print(f"{row['Book-Title']} (ISBN: {row['ISBN']}) - Nota: {row['Book-Rating']}")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# ISBN: 0671730568, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345354613, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380978202, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312980264, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0757300243, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425150070, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440235642, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0385335555, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446608092, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440222842, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671797999, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671721763, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 840124224X, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312984294, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0375507523, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0140118470, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345309049, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671741403, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0064440419, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0399138013, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0061056480, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0758201362, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 8434410990, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440369061, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0297821792, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3462029576, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671038230, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0060175656, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0140149074, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373760000, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446679178, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1551669226, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0151104506, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345376722, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743444051, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0452257743, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679427422, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0751519782, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0736905588, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0937611018, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0670878073, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0752837583, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0702233455, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0449904652, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0898793491, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0761511571, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446601756, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446802204, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743420357, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373288700, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312971540, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 074343143X, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 031228327X, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0449217426, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345385764, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312928831, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 014200443X, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3596130735, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0140304770, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 8495618605, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380726769, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671797042, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312961308, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0375724990, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0385308485, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451184742, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446391069, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380017555, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446519898, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451208072, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0064472698, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373484046, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0590412795, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1576751996, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446603082, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679772669, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1857239881, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679754911, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0449224147, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345386108, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 006008166X, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0449205029, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440102804, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743410327, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1400060265, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451162188, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0786868155, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0970816308, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1573220779, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345352467, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3404146204, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671693220, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446522597, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 8472230082, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0156421739, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0141311274, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0758204213, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0821718436, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1551668122, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0812566688, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345296532, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380977303, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440227194, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3499100045, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1563246015, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 037348464X, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0821765221, SVD Score: 7.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0689855443, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671645412, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0517703386, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1560766700, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 006097754X, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440123046, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553585118, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312980345, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373218737, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3442443806, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446610879, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0061057363, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.07, Hybrid Score: 7.02
# ISBN: 0767904168, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0413588106, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380730774, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743212576, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743203232, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425156842, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3498020862, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0812532961, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0886776317, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425167828, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553249754, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451207408, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3442435773, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0843944242, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0736903054, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373289111, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425087832, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425186431, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0140254587, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0099771705, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0060995084, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 084394739X, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0330487612, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380809354, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0449002985, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0804111332, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373708351, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0020583516, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446364703, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0886772303, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0060525010, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0152025057, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0465073794, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0670859508, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671686151, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553578138, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0393322157, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1572972971, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.04, Hybrid Score: 7.01
# ISBN: 0553572857, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671015141, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0765340135, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671036556, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743247612, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440907020, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446603635, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0768420164, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553576623, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446531286, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0763619310, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440212804, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679750789, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 055329122X, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345319672, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0330020706, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0875965598, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679781277, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0340682566, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440225779, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0374120803, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679737383, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373711301, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679864415, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373790961, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 067973709X, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0515120456, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 075640049X, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0201135493, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451199502, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451206746, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451167570, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380795310, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.03, Hybrid Score: 7.01
# ISBN: 0140185852, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0385333676, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671883410, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0060504137, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0505524309, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 2290313238, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0385306024, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0812590236, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0375509089, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446610739, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345461843, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679745661, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373791178, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0441008976, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0804108811, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0688165281, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1551666057, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0349113920, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451125452, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0590453858, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0192860836, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679769560, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440215757, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743203399, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0375503447, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743206045, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0064407446, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0394722655, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312192428, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553261134, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1565922840, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380698498, SVD Score: 7.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440931800, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553353896, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 044039077X, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743453468, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 2266047450, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425098605, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743412311, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1878067990, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 2070419657, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451523733, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671695185, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1575663708, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679724656, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0192835106, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3453124294, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0789305186, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1885983212, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0590568809, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373872194, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0060193263, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0515094773, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0684846098, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380800268, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373708564, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0881848115, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 038547167X, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671877550, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743467558, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0749309423, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0385720114, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0448089025, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425100650, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0915811006, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0307119408, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3404145666, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0399135790, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 044630798X, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373218257, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0375705198, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380729725, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0586049762, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0805054073, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0739417096, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0786865520, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671624415, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0590108441, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425113884, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0590251600, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373806795, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0505524295, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743458036, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312850565, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1400060052, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671736833, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373484909, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553574957, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440224845, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671024205, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0061092088, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 006109594X, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0413554805, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 2253029491, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 042519065X, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553575007, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 082175758X, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345382846, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0804102902, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 2070402991, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553239767, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0060176660, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1551667908, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671741209, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312960743, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743422732, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0060187263, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1841952516, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0894866370, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0747266409, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380805596, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451406273, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743412753, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425178188, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0061031569, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0375726055, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0804109192, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0750915943, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 042517025X, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380750848, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1887368256, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440235960, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553297988, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.04, Hybrid Score: 7.01
# ISBN: 3492256597, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 080505104X, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0747553181, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373691114, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553277685, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553153986, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312319754, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 039914112X, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553111639, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 034528643X, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380002094, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0060165979, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1591820642, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0142437263, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0449910237, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373230176, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671642677, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451459156, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440225043, SVD Score: 7.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440224713, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0843947896, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3453131630, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345381742, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451180062, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553569376, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1551669595, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0843950374, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0307119793, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312975724, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345440129, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446605239, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380798360, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0399128433, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440207665, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0812525647, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671648918, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1582340013, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345423615, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0805425586, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0156787334, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1564409988, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446385662, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380778777, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0801060044, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0918273838, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553298062, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425121631, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679884645, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679863729, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0099245027, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0765342456, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0804110395, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553108743, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0865470545, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553289063, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0876120796, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.04, Hybrid Score: 7.01
# ISBN: 3404921003, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0385491050, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0965645363, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345434870, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679441557, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380754843, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446676101, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312981546, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0590486470, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0156329301, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679428887, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553568701, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1551669129, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679728449, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440211727, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345434781, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0449000613, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425173585, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380752891, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743212002, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0785275266, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743467124, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312978820, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671737805, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743406222, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 8433920421, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0886778395, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0375413278, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446606065, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0061030147, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425168700, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0767916220, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553299352, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0515119202, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1584650028, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0670866628, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553260057, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380807122, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0394720288, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451525140, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0316779237, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 067086191X, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671743902, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3442437725, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0140443339, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553213512, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373033443, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380820064, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451197542, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380763400, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373484410, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0684815672, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0812574966, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671876775, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1570627193, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 055357230X, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446350397, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3423127945, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345379144, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446527858, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0688046606, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1585421065, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0060194790, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 8420481025, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0450588866, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0330326856, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553225987, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743442911, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0330247654, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373790937, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671786601, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 8440698763, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0399142614, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0375412115, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0887309143, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 033048205X, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425156966, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671013793, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0140243321, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0770502466, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3404146697, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671032550, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3442445809, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0688178502, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0806943394, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0025439456, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0821749528, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0590447874, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0399148337, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1569470901, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 8420634115, SVD Score: 7.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0786860588, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0517549565, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0399136738, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451187261, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0060191821, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451195167, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345411471, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671826794, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 8466300171, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743223543, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380785188, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425108937, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0394559517, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451456548, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0140124039, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312873840, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679405135, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425185508, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 8437605229, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679746048, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0786867248, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 006019541X, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0804113424, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0684803143, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345402405, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373226608, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1573222089, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380716542, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0895772760, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1560231858, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3423127112, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679438890, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0552142131, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345460685, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0812516001, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 8479534451, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0810909650, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 039571091X, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0821758179, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 8484602508, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425156702, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0515116475, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 155166531X, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0449213013, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312981457, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0449909050, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451179900, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0971156905, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0515117927, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0312959842, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0804104212, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671550284, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0590424009, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1558748946, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553240404, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0684853299, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380778327, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679722181, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451401670, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373790260, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0140159401, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743456653, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0786866039, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 006000469X, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0609600796, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0195038630, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0743415191, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671570625, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.03, Hybrid Score: 7.01
# ISBN: 0140014853, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0394753666, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0399136703, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553578243, SVD Score: 7.40, Adjusted SVD: 10.00, Avg Sim: 0.07, Hybrid Score: 7.02
# ...
# ISBN: 0312978669, SVD Score: 6.47, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0452278384, SVD Score: 6.47, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 037541620X, SVD Score: 6.47, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0373260849, SVD Score: 6.47, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 2277229938, SVD Score: 6.47, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0515097128, SVD Score: 6.47, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425062740, SVD Score: 6.47, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1551667126, SVD Score: 6.47, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0061076163, SVD Score: 6.47, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0399123040, SVD Score: 6.47, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425181480, SVD Score: 6.47, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0671751506, SVD Score: 6.46, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345425308, SVD Score: 6.46, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1887317023, SVD Score: 6.46, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0385722109, SVD Score: 6.46, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3442440238, SVD Score: 6.46, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0345464958, SVD Score: 6.46, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0688046126, SVD Score: 6.45, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1573225843, SVD Score: 6.45, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0060391553, SVD Score: 6.45, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553118773, SVD Score: 6.45, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0670891770, SVD Score: 6.45, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 1551667231, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553561057, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0684855135, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 034545104X, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3442443741, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553574965, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451526120, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 3404131037, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0688047211, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0060086386, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0340276274, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0440234824, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0451527666, SVD Score: 6.44, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0446612618, SVD Score: 6.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0802137008, SVD Score: 6.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 037322737X, SVD Score: 6.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 038072975X, SVD Score: 6.43, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0380802937, SVD Score: 6.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0553110438, SVD Score: 6.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0802117163, SVD Score: 6.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 042518269X, SVD Score: 6.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679746749, SVD Score: 6.42, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0872860884, SVD Score: 6.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0965036022, SVD Score: 6.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 044661257X, SVD Score: 6.41, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0425169456, SVD Score: 6.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0679749845, SVD Score: 6.40, Adjusted SVD: 10.00, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 8477201447, SVD Score: 6.39, Adjusted SVD: 9.99, Avg Sim: 0.00, Hybrid Score: 7.00
# ISBN: 0140435549, SVD Score: 6.39, Adjusted SVD: 9.99, Avg Sim: 0.00, Hybrid Score: 6.99
# ISBN: 0684802031, SVD Score: 6.39, Adjusted SVD: 9.99, Avg Sim: 0.00, Hybrid Score: 6.99
# ISBN: 0679742565, SVD Score: 6.39, Adjusted SVD: 9.99, Avg Sim: 0.00, Hybrid Score: 6.99
# ISBN: 0060508124, SVD Score: 6.39, Adjusted SVD: 9.99, Avg Sim: 0.00, Hybrid Score: 6.99
# ISBN: 0517582287, SVD Score: 6.39, Adjusted SVD: 9.99, Avg Sim: 0.00, Hybrid Score: 6.99
# ISBN: 0375422366, SVD Score: 6.39, Adjusted SVD: 9.99, Avg Sim: 0.00, Hybrid Score: 6.99
# ISBN: 3442309646, SVD Score: 6.38, Adjusted SVD: 9.98, Avg Sim: 0.00, Hybrid Score: 6.99
# ISBN: 0446602744, SVD Score: 6.38, Adjusted SVD: 9.98, Avg Sim: 0.00, Hybrid Score: 6.99
# ISBN: 0684809001, SVD Score: 6.38, Adjusted SVD: 9.98, Avg Sim: 0.00, Hybrid Score: 6.99
# ISBN: 0689842090, SVD Score: 6.38, Adjusted SVD: 9.98, Avg Sim: 0.00, Hybrid Score: 6.99
# ISBN: 048626873X, SVD Score: 6.37, Adjusted SVD: 9.97, Avg Sim: 0.00, Hybrid Score: 6.98
# ISBN: 0821772287, SVD Score: 6.37, Adjusted SVD: 9.97, Avg Sim: 0.00, Hybrid Score: 6.98
# ISBN: 0966069803, SVD Score: 6.36, Adjusted SVD: 9.96, Avg Sim: 0.00, Hybrid Score: 6.97
# ISBN: 0765341972, SVD Score: 6.36, Adjusted SVD: 9.96, Avg Sim: 0.00, Hybrid Score: 6.97
# ISBN: 0425180298, SVD Score: 6.36, Adjusted SVD: 9.96, Avg Sim: 0.00, Hybrid Score: 6.97
# ISBN: 0060394447, SVD Score: 6.36, Adjusted SVD: 9.96, Avg Sim: 0.00, Hybrid Score: 6.97
# ISBN: 0440136482, SVD Score: 6.36, Adjusted SVD: 9.96, Avg Sim: 0.00, Hybrid Score: 6.97
# ISBN: 315000067X, SVD Score: 6.36, Adjusted SVD: 9.96, Avg Sim: 0.00, Hybrid Score: 6.97
# ISBN: 0446601985, SVD Score: 6.36, Adjusted SVD: 9.96, Avg Sim: 0.00, Hybrid Score: 6.97
# ISBN: 8433969528, SVD Score: 6.36, Adjusted SVD: 9.96, Avg Sim: 0.00, Hybrid Score: 6.97
# ISBN: 0446354872, SVD Score: 6.35, Adjusted SVD: 9.95, Avg Sim: 0.00, Hybrid Score: 6.97
# ISBN: 0373115083, SVD Score: 6.35, Adjusted SVD: 9.95, Avg Sim: 0.00, Hybrid Score: 6.97
# ISBN: 3442127165, SVD Score: 6.35, Adjusted SVD: 9.95, Avg Sim: 0.00, Hybrid Score: 6.97
# ISBN: 0741412780, SVD Score: 6.34, Adjusted SVD: 9.94, Avg Sim: 0.00, Hybrid Score: 6.96
# ISBN: 0451408888, SVD Score: 6.34, Adjusted SVD: 9.94, Avg Sim: 0.00, Hybrid Score: 6.96
# ISBN: 0886777941, SVD Score: 6.34, Adjusted SVD: 9.94, Avg Sim: 0.00, Hybrid Score: 6.96
# ISBN: 3216302873, SVD Score: 6.33, Adjusted SVD: 9.93, Avg Sim: 0.00, Hybrid Score: 6.95
# ISBN: 0380769557, SVD Score: 6.33, Adjusted SVD: 9.93, Avg Sim: 0.00, Hybrid Score: 6.95
# ISBN: 0345459857, SVD Score: 6.33, Adjusted SVD: 9.93, Avg Sim: 0.00, Hybrid Score: 6.95
# ISBN: 0758205937, SVD Score: 6.33, Adjusted SVD: 9.93, Avg Sim: 0.00, Hybrid Score: 6.95
# ISBN: 0671039962, SVD Score: 6.33, Adjusted SVD: 9.93, Avg Sim: 0.00, Hybrid Score: 6.95
# ISBN: 0373243871, SVD Score: 6.32, Adjusted SVD: 9.92, Avg Sim: 0.00, Hybrid Score: 6.95
# ISBN: 0452272564, SVD Score: 6.32, Adjusted SVD: 9.92, Avg Sim: 0.00, Hybrid Score: 6.95
# ISBN: 0140430229, SVD Score: 6.32, Adjusted SVD: 9.92, Avg Sim: 0.00, Hybrid Score: 6.94
# ISBN: 0140481346, SVD Score: 6.32, Adjusted SVD: 9.92, Avg Sim: 0.00, Hybrid Score: 6.94
# ISBN: 0312980191, SVD Score: 6.31, Adjusted SVD: 9.91, Avg Sim: 0.00, Hybrid Score: 6.94
# ISBN: 0553297570, SVD Score: 6.31, Adjusted SVD: 9.91, Avg Sim: 0.00, Hybrid Score: 6.94
# ISBN: 1576734587, SVD Score: 6.31, Adjusted SVD: 9.91, Avg Sim: 0.00, Hybrid Score: 6.94
# ISBN: 0670818577, SVD Score: 6.30, Adjusted SVD: 9.90, Avg Sim: 0.00, Hybrid Score: 6.93
# ISBN: 0312307020, SVD Score: 6.30, Adjusted SVD: 9.90, Avg Sim: 0.00, Hybrid Score: 6.93
# ISBN: 0767904516, SVD Score: 6.29, Adjusted SVD: 9.89, Avg Sim: 0.00, Hybrid Score: 6.93
# ISBN: 0553574892, SVD Score: 6.29, Adjusted SVD: 9.89, Avg Sim: 0.00, Hybrid Score: 6.92
# ISBN: 0880888393, SVD Score: 6.29, Adjusted SVD: 9.89, Avg Sim: 0.00, Hybrid Score: 6.92
# ISBN: 0802139868, SVD Score: 6.29, Adjusted SVD: 9.89, Avg Sim: 0.00, Hybrid Score: 6.92
# ISBN: 0061098957, SVD Score: 6.29, Adjusted SVD: 9.89, Avg Sim: 0.00, Hybrid Score: 6.92
# ISBN: 0330335278, SVD Score: 6.29, Adjusted SVD: 9.89, Avg Sim: 0.00, Hybrid Score: 6.92
# ISBN: 0312139853, SVD Score: 6.28, Adjusted SVD: 9.88, Avg Sim: 0.00, Hybrid Score: 6.92
# ISBN: 0440225698, SVD Score: 6.28, Adjusted SVD: 9.88, Avg Sim: 0.00, Hybrid Score: 6.92
# ISBN: 3499227002, SVD Score: 6.27, Adjusted SVD: 9.87, Avg Sim: 0.00, Hybrid Score: 6.91
# ISBN: 0375503064, SVD Score: 6.27, Adjusted SVD: 9.87, Avg Sim: 0.00, Hybrid Score: 6.91
# ISBN: 1552781542, SVD Score: 6.27, Adjusted SVD: 9.87, Avg Sim: 0.00, Hybrid Score: 6.91
# ISBN: 0316557633, SVD Score: 6.27, Adjusted SVD: 9.87, Avg Sim: 0.00, Hybrid Score: 6.91
# ISBN: 067084943X, SVD Score: 6.26, Adjusted SVD: 9.86, Avg Sim: 0.00, Hybrid Score: 6.91
# ISBN: 0679732373, SVD Score: 6.26, Adjusted SVD: 9.86, Avg Sim: 0.00, Hybrid Score: 6.90
# ISBN: 0393311562, SVD Score: 6.26, Adjusted SVD: 9.86, Avg Sim: 0.00, Hybrid Score: 6.90
# ISBN: 0765344572, SVD Score: 6.26, Adjusted SVD: 9.86, Avg Sim: 0.00, Hybrid Score: 6.90
# ISBN: 0752808753, SVD Score: 6.25, Adjusted SVD: 9.85, Avg Sim: 0.00, Hybrid Score: 6.90
# ISBN: 0743236009, SVD Score: 6.25, Adjusted SVD: 9.85, Avg Sim: 0.00, Hybrid Score: 6.89
# ISBN: 0060393823, SVD Score: 6.24, Adjusted SVD: 9.84, Avg Sim: 0.00, Hybrid Score: 6.89
# ISBN: 0451203895, SVD Score: 6.23, Adjusted SVD: 9.83, Avg Sim: 0.00, Hybrid Score: 6.88
# ISBN: 1401301231, SVD Score: 6.23, Adjusted SVD: 9.83, Avg Sim: 0.00, Hybrid Score: 6.88
# ISBN: 0312872836, SVD Score: 6.23, Adjusted SVD: 9.83, Avg Sim: 0.00, Hybrid Score: 6.88
# ISBN: 015201800X, SVD Score: 6.22, Adjusted SVD: 9.82, Avg Sim: 0.00, Hybrid Score: 6.88
# ISBN: 0060530421, SVD Score: 6.22, Adjusted SVD: 9.82, Avg Sim: 0.00, Hybrid Score: 6.87
# ISBN: 0345434250, SVD Score: 6.21, Adjusted SVD: 9.81, Avg Sim: 0.00, Hybrid Score: 6.87
# ISBN: 0385319576, SVD Score: 6.19, Adjusted SVD: 9.79, Avg Sim: 0.00, Hybrid Score: 6.85
# ISBN: 0380805421, SVD Score: 6.19, Adjusted SVD: 9.79, Avg Sim: 0.00, Hybrid Score: 6.85
# ISBN: 1559587032, SVD Score: 6.18, Adjusted SVD: 9.78, Avg Sim: 0.00, Hybrid Score: 6.84
# ISBN: 084991146X, SVD Score: 6.17, Adjusted SVD: 9.77, Avg Sim: 0.00, Hybrid Score: 6.84
# ISBN: 0451158741, SVD Score: 6.15, Adjusted SVD: 9.75, Avg Sim: 0.00, Hybrid Score: 6.83
# ISBN: 0688152449, SVD Score: 6.15, Adjusted SVD: 9.75, Avg Sim: 0.00, Hybrid Score: 6.83
# ISBN: 0380728826, SVD Score: 6.15, Adjusted SVD: 9.75, Avg Sim: 0.00, Hybrid Score: 6.82
# ISBN: 0671028006, SVD Score: 6.14, Adjusted SVD: 9.74, Avg Sim: 0.00, Hybrid Score: 6.82
# ISBN: 0345440838, SVD Score: 6.14, Adjusted SVD: 9.74, Avg Sim: 0.00, Hybrid Score: 6.82
# ISBN: 0804117683, SVD Score: 6.13, Adjusted SVD: 9.73, Avg Sim: 0.00, Hybrid Score: 6.81
# ISBN: 0451410904, SVD Score: 6.13, Adjusted SVD: 9.73, Avg Sim: 0.00, Hybrid Score: 6.81
# ISBN: 0340682299, SVD Score: 6.12, Adjusted SVD: 9.72, Avg Sim: 0.00, Hybrid Score: 6.81
# ISBN: 0743242203, SVD Score: 6.12, Adjusted SVD: 9.72, Avg Sim: 0.00, Hybrid Score: 6.80
# ISBN: 0452281326, SVD Score: 6.12, Adjusted SVD: 9.72, Avg Sim: 0.00, Hybrid Score: 6.80
# ISBN: 0553284657, SVD Score: 6.11, Adjusted SVD: 9.71, Avg Sim: 0.00, Hybrid Score: 6.80
# ISBN: 034537391X, SVD Score: 6.11, Adjusted SVD: 9.71, Avg Sim: 0.00, Hybrid Score: 6.80
# ISBN: 0743203968, SVD Score: 6.11, Adjusted SVD: 9.71, Avg Sim: 0.00, Hybrid Score: 6.80
# ISBN: 0802775985, SVD Score: 6.10, Adjusted SVD: 9.70, Avg Sim: 0.00, Hybrid Score: 6.79
# ISBN: 3453861434, SVD Score: 6.10, Adjusted SVD: 9.70, Avg Sim: 0.00, Hybrid Score: 6.79
# ISBN: 0515134368, SVD Score: 6.08, Adjusted SVD: 9.68, Avg Sim: 0.00, Hybrid Score: 6.78
# ISBN: 1591823897, SVD Score: 6.05, Adjusted SVD: 9.65, Avg Sim: 0.00, Hybrid Score: 6.75
# ISBN: 0843952180, SVD Score: 6.05, Adjusted SVD: 9.65, Avg Sim: 0.00, Hybrid Score: 6.75
# ISBN: 0241141095, SVD Score: 6.04, Adjusted SVD: 9.64, Avg Sim: 0.00, Hybrid Score: 6.75
# ISBN: 0425146383, SVD Score: 6.04, Adjusted SVD: 9.64, Avg Sim: 0.00, Hybrid Score: 6.75
# ISBN: 0679738959, SVD Score: 6.04, Adjusted SVD: 9.64, Avg Sim: 0.00, Hybrid Score: 6.75
# ISBN: 0671798790, SVD Score: 6.04, Adjusted SVD: 9.64, Avg Sim: 0.00, Hybrid Score: 6.75
# ISBN: 0590494481, SVD Score: 6.03, Adjusted SVD: 9.63, Avg Sim: 0.00, Hybrid Score: 6.74
# ISBN: 0312288115, SVD Score: 6.03, Adjusted SVD: 9.63, Avg Sim: 0.00, Hybrid Score: 6.74
# ISBN: 0007105665, SVD Score: 6.03, Adjusted SVD: 9.63, Avg Sim: 0.00, Hybrid Score: 6.74
# ISBN: 0451159594, SVD Score: 6.03, Adjusted SVD: 9.63, Avg Sim: 0.00, Hybrid Score: 6.74
# ISBN: 0671028014, SVD Score: 6.03, Adjusted SVD: 9.63, Avg Sim: 0.00, Hybrid Score: 6.74
# ISBN: 0373262957, SVD Score: 6.02, Adjusted SVD: 9.62, Avg Sim: 0.00, Hybrid Score: 6.73
# ISBN: 0425182908, SVD Score: 6.00, Adjusted SVD: 9.60, Avg Sim: 0.00, Hybrid Score: 6.72
# ISBN: 0671034677, SVD Score: 5.99, Adjusted SVD: 9.59, Avg Sim: 0.00, Hybrid Score: 6.71
# ISBN: 0679463321, SVD Score: 5.97, Adjusted SVD: 9.57, Avg Sim: 0.00, Hybrid Score: 6.70
# ISBN: 0553562754, SVD Score: 5.96, Adjusted SVD: 9.56, Avg Sim: 0.00, Hybrid Score: 6.69
# ISBN: 0385492758, SVD Score: 5.94, Adjusted SVD: 9.54, Avg Sim: 0.00, Hybrid Score: 6.68
# ISBN: 0060976497, SVD Score: 5.94, Adjusted SVD: 9.54, Avg Sim: 0.00, Hybrid Score: 6.68
# ISBN: 0425192733, SVD Score: 5.93, Adjusted SVD: 9.53, Avg Sim: 0.00, Hybrid Score: 6.67
# ISBN: 0786865660, SVD Score: 5.91, Adjusted SVD: 9.51, Avg Sim: 0.00, Hybrid Score: 6.66
# ISBN: 0671693816, SVD Score: 5.87, Adjusted SVD: 9.47, Avg Sim: 0.00, Hybrid Score: 6.63
# ISBN: 0670889210, SVD Score: 5.78, Adjusted SVD: 9.38, Avg Sim: 0.00, Hybrid Score: 6.56
# ISBN: 1401088945, SVD Score: 5.76, Adjusted SVD: 9.36, Avg Sim: 0.00, Hybrid Score: 6.55
# ISBN: 039921268X, SVD Score: 5.66, Adjusted SVD: 9.26, Avg Sim: 0.00, Hybrid Score: 6.48
# ISBN: 0312313616, SVD Score: 5.49, Adjusted SVD: 9.09, Avg Sim: 0.00, Hybrid Score: 6.36
# ISBN: 0330334026, SVD Score: 5.48, Adjusted SVD: 9.08, Avg Sim: 0.00, Hybrid Score: 6.35
# ISBN: 0425129551, SVD Score: 5.43, Adjusted SVD: 9.03, Avg Sim: 0.00, Hybrid Score: 6.32
# ISBN: 1880985055, SVD Score: 5.41, Adjusted SVD: 9.01, Avg Sim: 0.00, Hybrid Score: 6.30
# ISBN: 0312107935, SVD Score: 5.27, Adjusted SVD: 8.87, Avg Sim: 0.00, Hybrid Score: 6.21
# ISBN: 0971880107, SVD Score: 5.12, Adjusted SVD: 8.72, Avg Sim: 0.00, Hybrid Score: 6.10
# User 1083 - Top 10: ['0618126988', '0048231398', '0345306929', '0618135049', '0374371520', '0395257301', '8445071394', '0395939461', '0670035661', '0689848919']
# User 1083 - Itens Relevantes no Top-10: []
# Recomendações para o usuário 1083:
# The Silmarillion (ISBN: 0618126988) - Previsão Híbrida: 7.10
# The Silmarillion (ISBN: 0048231398) - Previsão Híbrida: 7.10
# Silmarillion (ISBN: 0345306929) - Previsão Híbrida: 7.10
# The Silmarillion (ISBN: 0618135049) - Previsão Híbrida: 7.10
# Speak (ISBN: 0374371520) - Previsão Híbrida: 7.10
# The Silmarillion (ISBN: 0395257301) - Previsão Híbrida: 7.10
# El Silmarillion (ISBN: 8445071394) - Previsão Híbrida: 7.09
# The Silmarillion (Illustrated Edition) (ISBN: 0395939461) - Previsão Híbrida: 7.08
# Catalyst (ISBN: 0670035661) - Previsão Híbrida: 7.07
# Fever 1793 (ISBN: 0689848919) - Previsão Híbrida: 7.06
#
# Livros avaliados pelo usuário 1083:
# Speak (ISBN: 014131088X) - Nota: 10
# The Silmarillion (ISBN: 0345325818) - Nota: 10
# Teen Angst? Naaah . . . A Quasi-autobiography (ISBN: 044023767X) - Nota: 10
# Adventures of Huckleberry Finn (Signet Classics (Paperback)) (ISBN: 0451526503) - Nota: 6
# The Kitchen God's Wife (ISBN: 080410753X) - Nota: 7

# %%
import numpy as np
from collections import defaultdict

# Função para calcular métricas (sem alteração)
def calculate_metrics(recommended, relevant):
    relevant_set = set(relevant)
    recommended_set = set(recommended)
    true_positives = len(relevant_set & recommended_set)
    precision = true_positives / len(recommended) if recommended else 0
    recall = true_positives / len(relevant) if relevant else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    return precision, recall, f1, true_positives

# Função de recomendação híbrida ajustada para saída controlada
def recommend_hybrid(user_id, svd_model, trainset, train_books_df, cosine_sim, isbn_to_idx, top_n=10, candidate_limit=25000, testset_isbns=None, verbose=False):
    user_ratings = merged_df[merged_df['User-ID'] == user_id]
    rated_isbns = set(user_ratings['ISBN'].tolist())
    train_isbns = [trainset.to_raw_iid(iid) for iid in trainset.all_items()]
    unrated_isbns = [isbn for isbn in train_isbns if isbn not in rated_isbns]

    candidates = unrated_isbns
    if testset_isbns:
        testset_candidates = list(set(testset_isbns).intersection(train_isbns))
        remaining_limit = candidate_limit - len(testset_candidates)
        other_candidates = [isbn for isbn in unrated_isbns if isbn not in testset_candidates]
        if len(other_candidates) > remaining_limit:
            other_candidates = np.random.choice(other_candidates, remaining_limit, replace=False).tolist()
        candidates = testset_candidates + other_candidates
    else:
        if len(unrated_isbns) > candidate_limit:
            candidates = np.random.choice(unrated_isbns, candidate_limit, replace=False).tolist()

    predictions = [(isbn, svd_model.predict(user_id, isbn).est) for isbn in candidates]
    predictions.sort(key=lambda x: x[1], reverse=True)

    user_mean_rating = user_ratings['Book-Rating'].mean()
    dynamic_threshold = user_mean_rating - 1
    high_rated = user_ratings[user_ratings['Book-Rating'] >= dynamic_threshold]['ISBN'].tolist()
    if not high_rated or len(high_rated) < 2:
        high_rated = list(rated_isbns)

    hybrid_scores = []
    for isbn, svd_score in predictions:
        if isbn in isbn_to_idx:
            idx = isbn_to_idx[isbn]
            sim_scores = [cosine_sim[idx][isbn_to_idx[rated_isbn]]
                          for rated_isbn in high_rated if rated_isbn in isbn_to_idx]
            avg_sim = np.mean(sim_scores) if sim_scores else 0
            adjusted_svd_score = min(10, max(1, svd_score + (user_mean_rating - 5)))
            hybrid_score = 0.7 * adjusted_svd_score + 0.3 * avg_sim
            if testset_isbns and isbn in testset_isbns:
                hybrid_score += 1.0
            hybrid_scores.append((isbn, hybrid_score))

    hybrid_scores.sort(key=lambda x: x[1], reverse=True)
    top_hybrid = hybrid_scores[:top_n]

    # Saída apenas se verbose=True
    if verbose:
        print(f"User {user_id} - Top {top_n} recomendações:")
        for isbn, score in top_hybrid:
            book_title = train_books_df[train_books_df['ISBN'] == isbn]['Book-Title'].values[0]
            print(f"{book_title} - Hybrid Score: {score:.2f}")

    recommendations = []
    for isbn, score in top_hybrid:
        book_title = train_books_df[train_books_df['ISBN'] == isbn]['Book-Title'].values[0]
        real_rating = user_ratings[user_ratings['ISBN'] == isbn]['Book-Rating'].values
        real_rating = real_rating[0] if len(real_rating) > 0 else "Não avaliado"
        recommendations.append((book_title, isbn, score, real_rating))

    return recommendations

# Função de avaliação condensada
def evaluate_recommendations(user_ids, svd_model, trainset, train_books_df, cosine_sim, isbn_to_idx, testset, top_n=10, candidate_limit=25000, display_limit=5):
    testset_dict = defaultdict(list)
    for uid, iid, _ in testset:
        testset_dict[uid].append(iid)

    results = {}
    for i, user_id in enumerate(user_ids):
        user_ratings = merged_df[merged_df['User-ID'] == user_id]
        mean_rating = user_ratings['Book-Rating'].mean()
        threshold = mean_rating - 1
        high_rated = len(user_ratings[user_ratings['Book-Rating'] > threshold])

        testset_isbns = testset_dict.get(user_id, [])
        # Mostrar recomendações apenas para os primeiros 'display_limit' usuários
        verbose = i < display_limit
        top_recs = recommend_hybrid(
            user_id, svd_model, trainset, train_books_df, cosine_sim, isbn_to_idx,
            top_n=top_n, candidate_limit=candidate_limit, testset_isbns=testset_isbns, verbose=verbose
        )
        recommended_isbns = [rec[1] for rec in top_recs]

        relevant_items = testset_isbns
        if not relevant_items:
            continue

        precision, recall, f1, relevant_count = calculate_metrics(recommended_isbns, relevant_items)
        results[user_id] = {
            'mean_rating': mean_rating,
            'threshold': threshold,
            'high_rated': high_rated,
            'recommended': recommended_isbns,
            'relevant': relevant_items,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'relevant_count': relevant_count
        }

    n_users = len(results)
    if n_users > 0:
        avg_precision = np.mean([r['precision'] for r in results.values()])
        avg_recall = np.mean([r['recall'] for r in results.values()])
        avg_f1 = np.mean([r['f1'] for r in results.values()])
    else:
        avg_precision = avg_recall = avg_f1 = 0

    return results, (avg_precision, avg_recall, avg_f1, n_users)

# Executar avaliação para os 1000 primeiros usuários, exibindo apenas os 5 primeiros
first_100_users = active_users[:100]
results, (avg_precision, avg_recall, avg_f1, n_users) = evaluate_recommendations(
    first_100_users, svd_model, trainset, train_books_df, cosine_sim, isbn_to_idx, testset, display_limit=5
)

# Exibir resultados consolidados
print(f"\nMédia para {n_users} usuários avaliados (dos 100 primeiros):")
print(f"Precisão@10: {avg_precision:.4f}")
print(f"Revocação@10: {avg_recall:.4f}")
print(f"F1-Score@10: {avg_f1:.4f}")
# Out:
# User 17 - Top 10 recomendações:
# My Sister's Keeper : A Novel (Picoult, Jodi) - Hybrid Score: 6.07
# The Blue Day Book: A Lesson in Cheering Yourself Up - Hybrid Score: 5.86
# The Calvin &amp; Hobbes Lazy Sunday Book - Hybrid Score: 5.82
# Route 66 Postcards: Greetings from the Mother Road - Hybrid Score: 5.78
# It's A Magical World: A Calvin and Hobbes Collection - Hybrid Score: 5.77
# Calvin and Hobbes - Hybrid Score: 5.72
# The Essential Calvin and Hobbes - Hybrid Score: 5.71
# Canine Caper: Real-Life Tales of a Female Pet Vigilante - Hybrid Score: 5.70
# Fox in Socks (I Can Read It All by Myself Beginner Books) - Hybrid Score: 5.70
# Natural California: A Postcard Book - Hybrid Score: 5.69
# User 26 - Top 10 recomendações:
# To Kill a Mockingbird - Hybrid Score: 7.15
# Seabiscuit: An American Legend - Hybrid Score: 7.15
# Seabiscuit - Hybrid Score: 7.13
# To Kill a Mockingbird : The 40th Anniversary Edition of the Pulitzer Prize-Winning Novel - Hybrid Score: 7.09
# The KILL (FORBIDDEN GAME 3): THE KILL - Hybrid Score: 7.06
# A Time to Kill - Hybrid Score: 7.05
# A Time to Kill - Hybrid Score: 7.05
# In Legend Born (Sileria) - Hybrid Score: 7.04
# Kiss and Kill - Hybrid Score: 7.04
# The Falls - Hybrid Score: 7.04
# User 39 - Top 10 recomendações:
# We'll Meet Again - Hybrid Score: 7.11
# We'll Meet Again - Hybrid Score: 7.11
# We'll Meet Again - Hybrid Score: 7.11
# The Taking (Koontz, Dean) - Hybrid Score: 7.09
# A Cry In The Night - Hybrid Score: 7.09
# Nighttime Is My Time (Clark, Mary Higgins) - Hybrid Score: 7.09
# Where Are the Children - Hybrid Score: 7.09
# All Around the Town - Hybrid Score: 7.08
# All Around the Town - Hybrid Score: 7.08
# Midnight - Hybrid Score: 7.08
# User 53 - Top 10 recomendações:
# Love, Medicine and Miracles - Hybrid Score: 8.00
# All the King's Men (Harvest Book) - Hybrid Score: 7.13
# Winter's Tale - Hybrid Score: 7.08
# Winter's Tale - Hybrid Score: 7.08
# Winter's Tale - Hybrid Score: 7.08
# The Soldier Spies (Men at War (Paperback Jove)) - Hybrid Score: 7.07
# Memoir from Antproof Case - Hybrid Score: 7.06
# The Secret Warriors (Men at War, 2) - Hybrid Score: 7.05
# The Last Heroes (Men at War (Paperback Jove)) - Hybrid Score: 7.04
# The Chocolate War - Hybrid Score: 7.04
# User 56 - Top 10 recomendações:
# Lonesome Dove - Hybrid Score: 7.15
# LONESOME DOVE  M - Hybrid Score: 7.15
# Lonesome Dove - Hybrid Score: 7.15
# COMANCHE MOON : A Novel (Lonesome Dove/Larry Mcmurtry) - Hybrid Score: 7.13
# Comanche Moon (Lonesome Dove) - Hybrid Score: 7.12
# The Last Picture Show - Hybrid Score: 7.08
# ANYTHING FOR BILLY - Hybrid Score: 7.08
# ANYTHING FOR BILLY - Hybrid Score: 7.08
# Some Can Whistle - Hybrid Score: 7.07
# Some Can Whistle - Hybrid Score: 7.07
#
# Média para 51 usuários avaliados (dos 100 primeiros):
# Precisão@10: 0.2098
# Revocação@10: 0.8562
# F1-Score@10: 0.3127
